# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for x in array:
    print(x)

num = 0

while num < len(array):
    print(array[num])
    num += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
